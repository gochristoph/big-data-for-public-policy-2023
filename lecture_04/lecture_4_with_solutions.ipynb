# %%
# %matplotlib inline

import requests
import statsmodels.api as sm
import matplotlib.pyplot as plt
from tenacity import retry, stop_after_attempt, wait_fixed, wait_random, wait_random_exponential
import concurrent.futures
import csv
import logging

logging.basicConfig(format='%(asctime)s  %(message)s', datefmt='%y-%m-%d %H:%M:%S', level=logging.INFO)

# %% [markdown]
# # United Nations Statistics Division SDG API
#
# [**API Documentation**](https://unstats.un.org/sdgapi/swagger/#!/Series/V1SdgSeriesBySeriesCodeGeoAreaByGeoAreaCodeDataSliceGet)
#
# ## 1. Familiarizing with the API
#
# Tasks:
#
# 1. Request the data for **proportion of seats held by woman in national parliaments** (seriesCode=SG_GEN_PARL) for **Switzerland** (geoAreaCode=756) from the API using the `requests` module.
# 2. Create two lists *x* and *y* that contain the *year* and the *proportion of seats held by woman* respectively (make sure that the dict contain numbers).
# 3. Plot the data on a scatterplot with `matplotlib`.
# 4. Use `statsmodels` to perform an [OLS regression](https://www.statsmodels.org/dev/examples/notebooks/generated/ols.html) of the data.
# 5. Create a second scatter plot that also contains the regression line.

# %%
response = requests.get('https://unstats.un.org/sdgapi/v1/sdg/Series/SG_GEN_PARL/GeoArea/756/DataSlice')
# response.status_code
# response.headers
# response.content
# response.json()

# optional: timeit is a magic function that runs the code multiple times and returns the average time
# %timeit response = requests.get('https://unstats.un.org/sdgapi/v1/sdg/Series/SG_GEN_PARL/GeoArea/756/DataSlice')

# %%
# first, simplify the json
data = response.json()['dimensions']

x = [int(data[i]['timePeriodStart']) for i in range(len(response.json()['dimensions']))]
y = [float(data[i]['value']) for i in range(len(response.json()['dimensions']))]

# %%
plt.scatter(x, y)
plt.xlabel("year")
plt.ylabel("seats held by women (%)")
plt.show()

# %%
res = sm.OLS(y, sm.add_constant(x)).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     125.7
# Date:                Thu, 16 Mar 2023   Prob (F-statistic):           2.52e-10
# Time:                        04:45:03   Log-Likelihood:                -50.594
# No. Observations:                  23   AIC:                             105.2
# Df Residuals:                      21   BIC:                             107.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1589.9219    144.437    -11.008      0.000   -1890.295   -1289.549
# x1             0.8053      0.072     11.213      0.000       0.656       0.955
# ==============================================================================
# Omnibus:                        1.991   Durbin-Watson:                   0.689
# Prob(Omnibus):                  0.370   Jarque-Bera (JB):                1.542
# Skew:                           0.616   Prob(JB):                        0.463
# Kurtosis:                       2.700   Cond. No.                     6.10e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(x, y)
plt.plot(x, res.fittedvalues, 'k')
plt.xlabel("year")
plt.ylabel("seats held by women (%)")
plt.show()

# %% [markdown]
# ## 2. Parallelizing API requests
#
# API request normally come along with a comparably high latency and therefore are I/O bound. The same is true for web scraping, which is basically equivalent to API calls.
#
# Tasks:
# 1. Write a function that takes a geoAreaCode and obtains the data for the *proportion of seats held by woman in national parliaments* (seriesCode=SG_GEN_PARL)
# 2. Use `concurrent.futures` to parallelize API request (adapt [this example](https://docs.python.org/3/library/concurrent.futures.html#threadpoolexecutor-example)) so that you can obtain data for the geoAreaCodes below in parallel.
# 3. Write the data that you got from the API to a csv file with the following columns: **geoAreaCode**, **response_json**
# 4. Calculate the size of your speedup obtained by multithreading.

# %%
# all 248 countries/areas
geoAreaCodes = [4, 8, 12, 16, 20, 24, 28, 31, 32, 36, 40, 44, 48, 50, 51, 52, 56, 60, 64, 68, 70, 72, 74, 76, 84, 86, 
                90, 92, 96, 100, 104, 108, 112, 116, 120, 124, 132, 136, 140, 144, 148, 152, 156, 162, 166, 170, 174, 
                175, 178, 180, 184, 188, 191, 192, 196, 203, 204, 208, 212, 214, 218, 222, 226, 231, 232, 233, 234, 238, 
                239, 242, 246, 248, 250, 254, 258, 260, 262, 266, 268, 270, 275, 276, 288, 292, 296, 300, 304, 308, 312, 
                316, 320, 324, 328, 332, 334, 336, 340, 344, 348, 352, 356, 360, 364, 368, 372, 376, 380, 384, 388, 392, 
                398, 400, 404, 408, 410, 414, 417, 418, 422, 426, 428, 430, 434, 438, 440, 442, 446, 450, 454, 458, 462, 
                466, 470, 474, 478, 480, 484, 492, 496, 498, 499, 500, 504, 508, 512, 516, 520, 524, 528, 531, 533, 534, 
                535, 540, 548, 554, 558, 562, 566, 570, 574, 578, 580, 581, 583, 584, 585, 586, 591, 598, 600, 604, 608, 
                612, 616, 620, 624, 626, 630, 634, 638, 642, 643, 646, 652, 654, 659, 660, 662, 663, 666, 670, 674, 678, 
                680, 682, 686, 688, 690, 694, 702, 703, 704, 705, 706, 710, 716, 724, 728, 729, 732, 740, 744, 748, 752, 
                756, 760, 762, 764, 768, 772, 776, 780, 784, 788, 792, 795, 796, 798, 800, 804, 807, 818, 826, 831, 832, 
                833, 834, 840, 850, 854, 858, 860, 862, 876, 882, 887, 894]

# %% [markdown]
# **Gimmick**: You can uncomment and use the @retry decorator to automatically retry in case your internet connection breaks or the API is unresponsive for a moment. This way your script won't break because of these reasons.

# %%
@retry(stop=stop_after_attempt(4), wait=wait_random_exponential(multiplier=4,max=60))
def load_SG_GEN_PARL(geoAreaCode):
    url = f'https://unstats.un.org/sdgapi/v1/sdg/Series/SG_GEN_PARL/GeoArea/{geoAreaCode}/DataSlice'
    response = requests.get(url)
    return response.json()

# %%
with concurrent.futures.ThreadPoolExecutor(max_workers=40) as executor:
    # schedule the function load_SG_GEN_PARL to be executed in threads and mark each future (this is what 
    # executor.submit() returns as the key for the dictionary) with its geoAreaCode (the value in the dict)
    future_to_geoAreaCode = {executor.submit(load_SG_GEN_PARL, geoAreaCode): geoAreaCode for geoAreaCode in geoAreaCodes}
    
    # wait for the threads to finish (this whole part is optinal, but useful)
    for future in concurrent.futures.as_completed(future_to_geoAreaCode):
        geoAreaCode = future_to_geoAreaCode[future]
        try:
            json_response = future.result()
        except Exception as exc:
            logging.info(f'geoAreaCode {geoAreaCode}: failed with exception {exc}')
        else:
            logging.info(f'geoAreaCode {geoAreaCode}: success')
# Out:
# 23-03-16 04:45:09  geoAreaCode 16: success
# 23-03-16 04:45:09  geoAreaCode 12: success
# 23-03-16 04:45:09  geoAreaCode 32: success
# 23-03-16 04:45:09  geoAreaCode 24: success
# 23-03-16 04:45:09  geoAreaCode 20: success
# 23-03-16 04:45:09  geoAreaCode 28: success
# 23-03-16 04:45:09  geoAreaCode 8: success
# 23-03-16 04:45:09  geoAreaCode 86: success
# 23-03-16 04:45:09  geoAreaCode 36: success
# 23-03-16 04:45:09  geoAreaCode 51: success
# 23-03-16 04:45:10  geoAreaCode 31: success
# 23-03-16 04:45:10  geoAreaCode 44: success
# 23-03-16 04:45:10  geoAreaCode 4: success
# 23-03-16 04:45:10  geoAreaCode 48: success
# 23-03-16 04:45:10  geoAreaCode 68: success
# 23-03-16 04:45:10  geoAreaCode 136: success
# 23-03-16 04:45:10  geoAreaCode 40: success
# 23-03-16 04:45:10  geoAreaCode 64: success
# 23-03-16 04:45:10  geoAreaCode 120: success
# 23-03-16 04:45:10  geoAreaCode 124: success
# 23-03-16 04:45:10  geoAreaCode 104: success
# 23-03-16 04:45:10  geoAreaCode 90: success
# 23-03-16 04:45:10  geoAreaCode 52: success
# 23-03-16 04:45:10  geoAreaCode 92: success
# 23-03-16 04:45:10  geoAreaCode 74: success
# 23-03-16 04:45:10  geoAreaCode 60: success
# 23-03-16 04:45:10  geoAreaCode 84: success
# 23-03-16 04:45:10  geoAreaCode 72: success
# 23-03-16 04:45:10  geoAreaCode 100: success
# 23-03-16 04:45:10  geoAreaCode 108: success
# 23-03-16 04:45:10  geoAreaCode 96: success
# 23-03-16 04:45:10  geoAreaCode 56: success
# 23-03-16 04:45:10  geoAreaCode 140: success
# 23-03-16 04:45:10  geoAreaCode 50: success
# 23-03-16 04:45:10  geoAreaCode 162: success
# 23-03-16 04:45:10  geoAreaCode 166: success
# 23-03-16 04:45:10  geoAreaCode 70: success
# 23-03-16 04:45:10  geoAreaCode 175: success
# 23-03-16 04:45:10  geoAreaCode 148: success
# 23-03-16 04:45:10  geoAreaCode 116: success
# 23-03-16 04:45:10  geoAreaCode 76: success
# 23-03-16 04:45:10  geoAreaCode 144: success
# 23-03-16 04:45:10  geoAreaCode 132: success
# 23-03-16 04:45:10  geoAreaCode 152: success
# 23-03-16 04:45:10  geoAreaCode 156: success
# 23-03-16 04:45:10  geoAreaCode 184: success
# 23-03-16 04:45:10  geoAreaCode 170: success
# 23-03-16 04:45:10  geoAreaCode 112: success
# 23-03-16 04:45:11  geoAreaCode 191: success
# 23-03-16 04:45:11  geoAreaCode 178: success
# 23-03-16 04:45:11  geoAreaCode 174: success
# 23-03-16 04:45:11  geoAreaCode 238: success
# 23-03-16 04:45:11  geoAreaCode 234: success
# 23-03-16 04:45:11  geoAreaCode 180: success
# 23-03-16 04:45:11  geoAreaCode 248: success
# 23-03-16 04:45:11  geoAreaCode 239: success
# 23-03-16 04:45:11  geoAreaCode 212: success
# 23-03-16 04:45:11  geoAreaCode 218: success
# 23-03-16 04:45:11  geoAreaCode 204: success
# 23-03-16 04:45:11  geoAreaCode 196: success
# 23-03-16 04:45:11  geoAreaCode 258: success
# 23-03-16 04:45:11  geoAreaCode 203: success
# 23-03-16 04:45:11  geoAreaCode 260: success
# 23-03-16 04:45:11  geoAreaCode 192: success
# 23-03-16 04:45:11  geoAreaCode 226: success
# 23-03-16 04:45:11  geoAreaCode 208: success
# 23-03-16 04:45:11  geoAreaCode 222: success
# 23-03-16 04:45:11  geoAreaCode 254: success
# 23-03-16 04:45:11  geoAreaCode 233: success
# 23-03-16 04:45:11  geoAreaCode 232: success
# 23-03-16 04:45:11  geoAreaCode 292: success
# 23-03-16 04:45:11  geoAreaCode 231: success
# 23-03-16 04:45:11  geoAreaCode 250: success
# 23-03-16 04:45:11  geoAreaCode 188: success
# 23-03-16 04:45:11  geoAreaCode 275: success
# 23-03-16 04:45:11  geoAreaCode 304: success
# 23-03-16 04:45:11  geoAreaCode 242: success
# 23-03-16 04:45:11  geoAreaCode 262: success
# 23-03-16 04:45:11  geoAreaCode 214: success
# 23-03-16 04:45:11  geoAreaCode 246: success
# 23-03-16 04:45:11  geoAreaCode 266: success
# 23-03-16 04:45:11  geoAreaCode 312: success
# 23-03-16 04:45:11  geoAreaCode 316: success
# 23-03-16 04:45:11  geoAreaCode 268: success
# 23-03-16 04:45:11  geoAreaCode 288: success
# 23-03-16 04:45:11  geoAreaCode 276: success
# 23-03-16 04:45:11  geoAreaCode 296: success
# 23-03-16 04:45:11  geoAreaCode 270: success
# 23-03-16 04:45:11  geoAreaCode 334: success
# 23-03-16 04:45:11  geoAreaCode 308: success
# 23-03-16 04:45:11  geoAreaCode 300: success
# 23-03-16 04:45:11  geoAreaCode 336: success
# 23-03-16 04:45:12  geoAreaCode 344: success
# 23-03-16 04:45:12  geoAreaCode 324: success
# 23-03-16 04:45:12  geoAreaCode 332: success
# 23-03-16 04:45:12  geoAreaCode 328: success
# 23-03-16 04:45:12  geoAreaCode 364: success
# 23-03-16 04:45:12  geoAreaCode 360: success
# 23-03-16 04:45:12  geoAreaCode 384: success
# 23-03-16 04:45:12  geoAreaCode 380: success
# 23-03-16 04:45:12  geoAreaCode 348: success
# 23-03-16 04:45:12  geoAreaCode 408: success
# 23-03-16 04:45:12  geoAreaCode 352: success
# 23-03-16 04:45:12  geoAreaCode 340: success
# 23-03-16 04:45:12  geoAreaCode 446: success
# 23-03-16 04:45:12  geoAreaCode 422: success
# 23-03-16 04:45:12  geoAreaCode 356: success
# 23-03-16 04:45:12  geoAreaCode 434: success
# 23-03-16 04:45:12  geoAreaCode 400: success
# 23-03-16 04:45:12  geoAreaCode 474: success
# 23-03-16 04:45:12  geoAreaCode 410: success
# 23-03-16 04:45:12  geoAreaCode 404: success
# 23-03-16 04:45:12  geoAreaCode 428: success
# 23-03-16 04:45:12  geoAreaCode 392: success
# 23-03-16 04:45:12  geoAreaCode 438: success
# 23-03-16 04:45:12  geoAreaCode 458: success
# 23-03-16 04:45:12  geoAreaCode 430: success
# 23-03-16 04:45:12  geoAreaCode 440: success
# 23-03-16 04:45:13  geoAreaCode 426: success
# 23-03-16 04:45:13  geoAreaCode 466: success
# 23-03-16 04:45:13  geoAreaCode 320: success
# 23-03-16 04:45:13  geoAreaCode 498: success
# 23-03-16 04:45:13  geoAreaCode 418: success
# 23-03-16 04:45:13  geoAreaCode 442: success
# 23-03-16 04:45:13  geoAreaCode 478: success
# 23-03-16 04:45:13  geoAreaCode 368: success
# 23-03-16 04:45:13  geoAreaCode 500: success
# 23-03-16 04:45:13  geoAreaCode 470: success
# 23-03-16 04:45:13  geoAreaCode 388: success
# 23-03-16 04:45:13  geoAreaCode 533: success
# 23-03-16 04:45:13  geoAreaCode 372: success
# 23-03-16 04:45:13  geoAreaCode 480: success
# 23-03-16 04:45:13  geoAreaCode 570: success
# 23-03-16 04:45:13  geoAreaCode 376: success
# 23-03-16 04:45:13  geoAreaCode 414: success
# 23-03-16 04:45:13  geoAreaCode 462: success
# 23-03-16 04:45:13  geoAreaCode 534: success
# 23-03-16 04:45:13  geoAreaCode 496: success
# 23-03-16 04:45:13  geoAreaCode 540: success
# 23-03-16 04:45:13  geoAreaCode 484: success
# 23-03-16 04:45:13  geoAreaCode 450: success
# 23-03-16 04:45:13  geoAreaCode 512: success
# 23-03-16 04:45:13  geoAreaCode 492: success
# 23-03-16 04:45:13  geoAreaCode 504: success
# 23-03-16 04:45:13  geoAreaCode 574: success
# 23-03-16 04:45:13  geoAreaCode 508: success
# 23-03-16 04:45:14  geoAreaCode 578: success
# 23-03-16 04:45:14  geoAreaCode 580: success
# 23-03-16 04:45:14  geoAreaCode 454: success
# 23-03-16 04:45:14  geoAreaCode 499: success
# 23-03-16 04:45:14  geoAreaCode 531: success
# 23-03-16 04:45:14  geoAreaCode 581: success
# 23-03-16 04:45:14  geoAreaCode 398: success
# 23-03-16 04:45:14  geoAreaCode 417: success
# 23-03-16 04:45:14  geoAreaCode 548: success
# 23-03-16 04:45:14  geoAreaCode 524: success
# 23-03-16 04:45:14  geoAreaCode 528: success
# 23-03-16 04:45:14  geoAreaCode 535: success
# 23-03-16 04:45:14  geoAreaCode 566: success
# 23-03-16 04:45:14  geoAreaCode 516: success
# 23-03-16 04:45:14  geoAreaCode 520: success
# 23-03-16 04:45:14  geoAreaCode 612: success
# 23-03-16 04:45:14  geoAreaCode 638: success
# 23-03-16 04:45:14  geoAreaCode 583: success
# 23-03-16 04:45:14  geoAreaCode 585: success
# 23-03-16 04:45:14  geoAreaCode 558: success
# 23-03-16 04:45:14  geoAreaCode 554: success
# 23-03-16 04:45:14  geoAreaCode 562: success
# 23-03-16 04:45:14  geoAreaCode 652: success
# 23-03-16 04:45:14  geoAreaCode 630: success
# 23-03-16 04:45:14  geoAreaCode 654: success
# 23-03-16 04:45:14  geoAreaCode 584: success
# 23-03-16 04:45:14  geoAreaCode 660: success
# 23-03-16 04:45:14  geoAreaCode 608: success
# 23-03-16 04:45:14  geoAreaCode 663: success
# 23-03-16 04:45:14  geoAreaCode 666: success
# 23-03-16 04:45:14  geoAreaCode 600: success
# 23-03-16 04:45:14  geoAreaCode 620: success
# 23-03-16 04:45:14  geoAreaCode 598: success
# 23-03-16 04:45:14  geoAreaCode 624: success
# 23-03-16 04:45:14  geoAreaCode 591: success
# 23-03-16 04:45:14  geoAreaCode 586: success
# 23-03-16 04:45:14  geoAreaCode 604: success
# 23-03-16 04:45:15  geoAreaCode 616: success
# 23-03-16 04:45:15  geoAreaCode 680: success
# 23-03-16 04:45:15  geoAreaCode 626: success
# 23-03-16 04:45:15  geoAreaCode 674: success
# 23-03-16 04:45:15  geoAreaCode 634: success
# 23-03-16 04:45:15  geoAreaCode 642: success
# 23-03-16 04:45:15  geoAreaCode 646: success
# 23-03-16 04:45:15  geoAreaCode 643: success
# 23-03-16 04:45:15  geoAreaCode 659: success
# 23-03-16 04:45:15  geoAreaCode 670: success
# 23-03-16 04:45:15  geoAreaCode 662: success
# 23-03-16 04:45:15  geoAreaCode 729: success
# 23-03-16 04:45:15  geoAreaCode 772: success
# 23-03-16 04:45:15  geoAreaCode 682: success
# 23-03-16 04:45:15  geoAreaCode 710: success
# 23-03-16 04:45:15  geoAreaCode 690: success
# 23-03-16 04:45:15  geoAreaCode 686: success
# 23-03-16 04:45:15  geoAreaCode 744: success
# 23-03-16 04:45:15  geoAreaCode 688: success
# 23-03-16 04:45:15  geoAreaCode 728: success
# 23-03-16 04:45:15  geoAreaCode 702: success
# 23-03-16 04:45:15  geoAreaCode 796: success
# 23-03-16 04:45:15  geoAreaCode 724: success
# 23-03-16 04:45:15  geoAreaCode 752: success
# 23-03-16 04:45:15  geoAreaCode 678: success
# 23-03-16 04:45:16  geoAreaCode 776: success
# 23-03-16 04:45:16  geoAreaCode 706: success
# 23-03-16 04:45:16  geoAreaCode 732: success
# 23-03-16 04:45:16  geoAreaCode 703: success
# 23-03-16 04:45:16  geoAreaCode 748: success
# 23-03-16 04:45:16  geoAreaCode 798: success
# 23-03-16 04:45:16  geoAreaCode 832: success
# 23-03-16 04:45:16  geoAreaCode 756: success
# 23-03-16 04:45:16  geoAreaCode 850: success
# 23-03-16 04:45:16  geoAreaCode 762: success
# 23-03-16 04:45:16  geoAreaCode 764: success
# 23-03-16 04:45:16  geoAreaCode 818: success
# 23-03-16 04:45:16  geoAreaCode 788: success
# 23-03-16 04:45:16  geoAreaCode 716: success
# 23-03-16 04:45:16  geoAreaCode 760: success
# 23-03-16 04:45:16  geoAreaCode 784: success
# 23-03-16 04:45:16  geoAreaCode 876: success
# 23-03-16 04:45:16  geoAreaCode 694: success
# 23-03-16 04:45:16  geoAreaCode 792: success
# 23-03-16 04:45:16  geoAreaCode 833: success
# 23-03-16 04:45:16  geoAreaCode 705: success
# 23-03-16 04:45:16  geoAreaCode 807: success
# 23-03-16 04:45:16  geoAreaCode 795: success
# 23-03-16 04:45:16  geoAreaCode 704: success
# 23-03-16 04:45:16  geoAreaCode 831: success
# 23-03-16 04:45:16  geoAreaCode 804: success
# 23-03-16 04:45:16  geoAreaCode 800: success
# 23-03-16 04:45:16  geoAreaCode 887: success
# 23-03-16 04:45:16  geoAreaCode 740: success
# 23-03-16 04:45:17  geoAreaCode 894: success
# 23-03-16 04:45:17  geoAreaCode 854: success
# 23-03-16 04:45:17  geoAreaCode 768: success
# 23-03-16 04:45:17  geoAreaCode 834: success
# 23-03-16 04:45:17  geoAreaCode 840: success
# 23-03-16 04:45:17  geoAreaCode 826: success
# 23-03-16 04:45:17  geoAreaCode 858: success
# 23-03-16 04:45:17  geoAreaCode 780: success
# 23-03-16 04:45:17  geoAreaCode 860: success
# 23-03-16 04:45:17  geoAreaCode 882: success
# 23-03-16 04:45:17  geoAreaCode 862: success

# %%
header = ['geoAreaCode', 'response_json']

with open('api_responses.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    rows = [(geoAreaCode, future.result()) for future, geoAreaCode in future_to_geoAreaCode.items()]
    writer.writerows(rows)

# %% [markdown]
# With 40 threads, 248 API calls were finished in approximately 10 seconds. At the beginning of the notebook we saw that one API call takes roughly 0.5 seconds. The speed up when transitioning from one thread to 40 threads therefore is 248*0.5s/10s, so approximately 12.
